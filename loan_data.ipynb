# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HOME\OneDrive\Desktop\loan_data.csv")

print(df.head())
# Out:
#   Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    L001    Male      No         0.0  Not Graduate            No
# 1    L002    Male      No         2.0      Graduate           Yes
# 2    L003  Female     Yes         3.0  Not Graduate            No
# 3    L004  Female     Yes         2.0  Not Graduate           Yes
# 4    L005    Male     Yes         2.0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           4000.0              185.0       210.0             360.0
# 1           7568.0             2514.0       213.0             360.0
# 2           7710.0             1791.0       128.0             360.0
# 3           5195.0             1243.0       174.0             360.0
# 4           4999.0             2818.0       201.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           N
# 1             0.0     Semiurban           N
# 2             0.0         Urban           N
# 3             1.0         Rural           N
# 4             NaN         Rural           N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            200 non-null    object
#  1   Gender             200 non-null    object
#  2   Married            200 non-null    object
#  3   Dependents         200 non-null    float64
#  4   Education          200 non-null    object
#  5   Self_Employed      200 non-null    object
#  6   ApplicantIncome    200 non-null    float64
#  7   CoapplicantIncome  200 non-null    float64
#  8   LoanAmount         200 non-null    float64
#  9   Loan_Amount_Term   200 non-null    float64
#  10  Credit_History     193 non-null    float64
#  11  Property_Area      200 non-null    object
#  12  Loan_Status        200 non-null    object
# dtypes: float64(6), object(7)
# memory usage: 20.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID              1
# Gender               1
# Married              1
# Dependents           1
# Education            1
# Self_Employed        1
# ApplicantIncome      1
# CoapplicantIncome    1
# LoanAmount           1
# Loan_Amount_Term     1
# Credit_History       8
# Property_Area        1
# Loan_Status          1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 20

# %%
#remove duplicate
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df['Credit_History'] = df['Credit_History'].fillna(0)

# %%
#data analysis
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# N    91
# Y    89
# Name: count, dtype: int64

# %%
df['LoanAmount'].mean()
# Out:
# 152.10555555555555

# %%
df.groupby('Property_Area')['Loan_Status'].count()
# Out:
# Property_Area
# Rural        61
# Semiurban    63
# Urban        56
# Name: Loan_Status, dtype: int64

# %%
df.to_csv("clean_loan_data.csv", index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HOME
